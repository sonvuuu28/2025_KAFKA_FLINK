# %% [markdown]
# # Flink_tutorial

# %% [markdown]
# ## I. FLINK TERMINAL

# %% [markdown]
# ### 1. Terminal

# %% [markdown]
# ```bash
# docker exec -it flink-sql-client /bin/bash
# ```

# %% [markdown]
# ```bash
# /opt/flink/bin/sql-client.sh embedded
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## I. FLINK KẾT NỐI KAFKA

# %% [markdown]
# ### 1. Terminal

# %% [markdown]
# ```bash
# docker exec -it flink-sql-client /bin/bash
# ```

# %% [markdown]
# ```bash
# /opt/flink/bin/sql-client.sh embedded
# ```

# %% [markdown]
# ### 2. Tạo bảng

# %% [markdown]
# ```sql
# CREATE TABLE test_kafka (
#   msg STRING
# ) WITH (
#   'connector' = 'kafka',
#   'topic' = 'test-topic',
#   'properties.bootstrap.servers' = 'broker:29092',
#   'properties.group.id' = 'test-group',
#   'scan.startup.mode' = 'earliest-offset',
#   'format' = 'raw'
# );
# ```

# %% [markdown]
# ### 3. Kết quả

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
